# %% [markdown]
# # QMBU 450 : Final Project

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Reading Yahoo Financial Data for Apple

# %%
import pandas_datareader
import datetime

# %%
import pandas_datareader.data as web

# %%
start = pd.to_datetime('2010-01-01')
finish = pd.to_datetime('2020-01-01')

# %%
apple = web.DataReader('AAPL', 'yahoo', start, finish)
apple.to_csv("apple.csv")
# Out:
# (2516, 6)

# %% [markdown]
# # Plotting the Stock Market Data for Apple

# %%
apple['Adj Close'].plot(label='Adj Close',figsize=(16,10),title = 'Apple')
apple['Close'].plot(label='Close')
apple['Open'].plot(label='Open')
apple['High'].plot(label='High')
apple['Low'].plot(label='Low')
plt.legend();
plt.savefig('Apple_Stock_Data.png')

# %% [markdown]
# # Splitting the data into testing and training sets
# ## Preferred manually splitting, because I want my test set to come after the training set
# ### The split is 80/20

# %%
apple.dropna()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# 2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
# ...                ...         ...         ...         ...          ...
# 2019-12-24  284.890015  282.920013  284.690002  284.269989   12119700.0
# 2019-12-26  289.980011  284.700012  284.820007  289.910004   23280300.0
# 2019-12-27  293.970001  288.119995  291.119995  289.799988   36566500.0
# 2019-12-30  292.690002  285.220001  289.459991  291.519989   36028600.0
# 2019-12-31  293.679993  289.519989  289.929993  293.649994   25201400.0
#
#              Adj Close
# Date
# 2010-01-04   26.466835
# 2010-01-05   26.512596
# 2010-01-06   26.090879
# 2010-01-07   26.042646
# 2010-01-08   26.215786
# ...                ...
# 2019-12-24  282.831299
# 2019-12-26  288.442780
# 2019-12-27  288.333313
# 2019-12-30  290.044617
# 2019-12-31  292.163818
#
# [2516 rows x 6 columns]

# %%
split_date = pd.Timestamp('2018-01-01')

# %%
train = apple.loc[:split_date]
test = apple.loc[split_date:]

# %%
train = train.drop(['Volume'], axis=1)
test = test.drop(['Volume'], axis=1)

# %% [markdown]
# # Scale and Preprocess the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()

# %%
train_sc = sc.fit_transform(train)
test_sc = sc.fit_transform(test)

# %% [markdown]
# # Designing the model such that each previous data point will predict the next one

# %%
X_train = train_sc[:,:-1]
y_train = train_sc[:,-1:]

# %%
X_test = test_sc[:,:-1]
y_test = test_sc[:,-1:]

# %%
X_train_t = X_train[:,None]
X_test_t = X_test[:,None]

# %% [markdown]
# # Using LSTM to create the model
# ## 1. Defining the Network

# %%
model = Sequential()
model.add(LSTM(6, input_shape=(1,4)))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 2. Compiling the Network

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
early_stop = EarlyStopping(monitor='loss',patience=1,verbose=1,min_delta=5)

# %% [markdown]
# # Train the model

# %%
model.fit(X_train_t, y_train, epochs=20, batch_size=1, verbose=1, callbacks=[early_stop])
# Out:
# Train on 2013 samples
# Epoch 1/20
# 2013/2013 [==============================] - 9s 4ms/sample - loss: 0.0223
# Epoch 2/20
# 2013/2013 [==============================] - 6s 3ms/sample - loss: 0.0014
# Epoch 00002: early stopping

# %% [markdown]
# # Predictions on test set

# %%
y_pred = model.predict(X_test_t)

# %%
plt.figure(figsize=(16,8))
plt.plot(y_test)
plt.plot(y_pred)
plt.legend(['test','pred']);
plt.savefig('Test_Prediction_Comparison.png')

# %% [markdown]
# # Error Bar Plot

# %%
x = np.arange(y_pred.shape[0])

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.001524426391552455

# %%
yerr = y_pred - y_test

# %%
abs_error = np.absolute(yerr)

# %%
plt.figure(figsize=(16,8))
plt.errorbar(x[-60:], y_pred[-60:], yerr=abs_error[-60:], fmt='s', color='blue',
ecolor='lightblue', elinewidth=3, capsize=0);
plt.savefig('Error_Bar.png')
# Out:
# /Users/sitarearslanturk/opt/anaconda3/envs/qmbu450/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
